# %%
import logging
from logging import config as log_config
from pathlib import Path

import mlflow
import mlflow.sklearn
import optuna

from helpers.cli_options import get_cli_options_hpo
from helpers.mlflow_helpers import create_experiment, mlflow_callback
from helpers.optuna_helpers import objective, logging_callback
from helpers.pipeline import Anonymizer
from helpers.preprocessing import load_data

# %%
log_config.fileConfig(r"./log.conf")
logger = logging.getLogger(__name__)


base_folder = Path("../data/processed")
mlflow.tracking.set_tracking_uri("http://localhost:5000")

# %%
experiment = create_experiment(base_name="Sentiment")

# %%
def train_model(
    sample_size: int, workers: int, experiment: mlflow.entities.experiment.Experiment,
) -> None:
    logger.info("Load IMDB reviews")
    df_train, _ = load_data(folder=base_folder, sample_size=sample_size)

    # Anonymize data before pipeline, since this step is slow and constant
    logger.info("Preprocess reviews with spaCy. This may take a while..")
    anonymized_reviews = Anonymizer().transform(df_train.review)

    logger.info("Explore search space")
    study = optuna.create_study(direction="maximize")
    study.set_user_attr(key='experiment', value=experiment)

    study.optimize(
        lambda trial: objective(
            trial,
            X=anonymized_reviews[:10],
            y=df_train.sentiment[:10],
            workers=workers,
        ),
        n_trials=20,
        callbacks=[logging_callback, mlflow_callback],
    )

    return study

# %%
s = train_model(sample_size=10_000, workers=2, experiment=experiment)
# Out:
# INFO:: Load IMDB reviews
# INFO:: Preprocess reviews with spaCy. This may take a while..
# INFO:: Explore search space
# INFO:: Trial number: 0, ngram_range: 11, clf: MultinomialNB, alpha: 0.026068140154119183
# INFO:: Accuracy: 0.3611111111111111
# INFO:: Trial number: 1, ngram_range: 12, clf: RandomForestClassifier, max_depth: 2
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 2, ngram_range: 12, clf: RandomForestClassifier, max_depth: 2
# INFO:: Accuracy: 0.38888888888888884
# INFO:: Trial number: 3, ngram_range: 11, clf: SVC, C: 0.16847788581886447
# INFO:: Accuracy: 0.3055555555555555
# INFO:: Trial number: 4, ngram_range: 11, clf: MultinomialNB, alpha: 0.02365706569357498
# INFO:: Accuracy: 0.3611111111111111
# INFO:: Trial number: 5, ngram_range: 11, clf: SVC, C: 0.15135894230972707
# INFO:: Accuracy: 0.3055555555555555
# INFO:: Trial number: 6, ngram_range: 12, clf: SVC, C: 0.1433212999490459
# INFO:: Accuracy: 0.3055555555555555
# INFO:: Trial number: 7, ngram_range: 11, clf: SVC, C: 0.1758914497005484
# INFO:: Accuracy: 0.3055555555555555
# INFO:: Trial number: 8, ngram_range: 11, clf: SVC, C: 0.1743348470586979
# INFO:: Accuracy: 0.3055555555555555
# INFO:: Trial number: 9, ngram_range: 11, clf: RandomForestClassifier, max_depth: 2
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 10, ngram_range: 12, clf: RandomForestClassifier, max_depth: 4
# INFO:: Accuracy: 0.38888888888888884
# INFO:: Trial number: 11, ngram_range: 12, clf: RandomForestClassifier, max_depth: 4
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 12, ngram_range: 12, clf: RandomForestClassifier, max_depth: 4
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 13, ngram_range: 12, clf: RandomForestClassifier, max_depth: 3
# INFO:: Accuracy: 0.19444444444444442
# INFO:: Trial number: 14, ngram_range: 12, clf: RandomForestClassifier, max_depth: 3
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 15, ngram_range: 12, clf: RandomForestClassifier, max_depth: 2
# INFO:: Accuracy: 0.38888888888888884
# INFO:: Trial number: 16, ngram_range: 12, clf: RandomForestClassifier, max_depth: 4
# INFO:: Accuracy: 0.38888888888888884
# INFO:: Trial number: 17, ngram_range: 12, clf: MultinomialNB, alpha: 0.09920456095726199
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 18, ngram_range: 12, clf: RandomForestClassifier, max_depth: 2
# INFO:: Accuracy: 0.27777777777777773
# INFO:: Trial number: 19, ngram_range: 12, clf: RandomForestClassifier, max_depth: 3
# INFO:: Accuracy: 0.38888888888888884

# %%
s.best_trial.number
# Out:
# 2

# %%
run_id = mlflow.search_runs(
        experiment_ids=experiment.experiment_id)

# %%
run_id
# Out:
#                               run_id experiment_id    status  \
# 0   753a0e926ed74dc0810386f554fc10ed            54  FINISHED
# 1   fca40f4f11d34b7a97774e648dc9aa28            54  FINISHED
# 2   acc5d9d9ac4c4dea89e9d4c1533192c0            54  FINISHED
# 3   91bd001e2a2e4a53a76d897b3a26c634            54  FINISHED
# 4   c9c286ff1d484e6d9fe0573cf07d318c            54  FINISHED
# 5   900681ccdf0b4750bdbbd96d8279d541            54  FINISHED
# 6   bc4b00a5e56947728aaa610f30151bee            54  FINISHED
# 7   55b0790849b6469ca04a081a068ded81            54  FINISHED
# 8   0144359cdcb94b77b6fa8349b425efd2            54  FINISHED
# 9   cd5a0960e38d49d6bdd8dca0400b8f60            54  FINISHED
# 10  c0a9a2dbba9a42de9f6c771bbf18fe63            54  FINISHED
# 11  643dc170ffce40db9d18bf991fb6cfeb            54  FINISHED
# 12  5b66bb947e384682b6c2f60520b575b1            54  FINISHED
# 13  8b7da638541c4e2e8d0b79e4a899a058            54  FINISHED
# 14  85df0e0eb51342528ef4271cb2c9f7dc            54  FINISHED
# 15  f37b15bf0b0f4b339086c05565b3a9f7            54  FINISHED
# 16  4e7c93d02f51470fbec7376890540380            54  FINISHED
# 17  c8472b391916473fb6780ec6953f1657            54  FINISHED
# 18  1f5763a3bd834a6cbd09d718cb32f10f            54  FINISHED
# 19  c5224e59cb964154ba9e0148dc59ea1a            54  FINISHED
# 20  a1186ea7c78943daa5e90f58d03a8093            54  FINISHED
# 21  ed7d6f8984d94418b7fe8085740034b3            54  FINISHED
# 22  2d9ab4360b464f2daa16f20277f7c1ab            54  FINISHED
# 23  920fde8041f341d2872f481a53f8db44            54  FINISHED
# 24  9ee8e5141711426f88bcb87192fc45c1            54  FINISHED
# 25  7df12cb0cbee49f4aa13b934ed3fce16            54  FINISHED
# 26  bd073be95b154e698825a9754c66b851            54  FINISHED
# 27  7e25698ff58d48ce89d4378f50364177            54  FINISHED
# 28  7be59c30110f4eee8d6fe3173f93d011            54  FINISHED
# 29  c904d4dc9fb945ce9081e7870b638039            54  FINISHED
# 30  01dceee1951d4203a8038b3b35696cb7            54  FINISHED
# 31  4e075d845ae6420384929d630a416a5c            54  FINISHED
# 32  4457484e8ee14709acd15586dd1f5686            54  FINISHED
# 33  3049264db5aa43519d1289c90d5eda41            54  FINISHED
# 34  36fa84abc6b34b878bd16866950be975            54  FINISHED
# 35  b3736dd215614ac28925498cffa3d1fa            54  FINISHED
# 36  93fb494bbe5e495db87a978e6b89d824            54  FINISHED
# 37  c820c40f3e3847aaa7aa6fedb1770786            54  FINISHED
# 38  b6360a1cd13f4509ada8d3ca7873a4ad            54  FINISHED
# 39  f4a9a0809b1d4f0fb2d76184299b27e9            54  FINISHED
#
#                                          artifact_uri  \
# 0   ../data/artifacts/54/753a0e926ed74dc0810386f55...
# 1   ../data/artifacts/54/fca40f4f11d34b7a97774e648...
# 2   ../data/artifacts/54/acc5d9d9ac4c4dea89e9d4c15...
# 3   ../data/artifacts/54/91bd001e2a2e4a53a76d897b3...
# 4   ../data/artifacts/54/c9c286ff1d484e6d9fe0573cf...
# 5   ../data/artifacts/54/900681ccdf0b4750bdbbd96d8...
# 6   ../data/artifacts/54/bc4b00a5e56947728aaa610f3...
# 7   ../data/artifacts/54/55b0790849b6469ca04a081a0...
# 8   ../data/artifacts/54/0144359cdcb94b77b6fa8349b...
# 9   ../data/artifacts/54/cd5a0960e38d49d6bdd8dca04...
# 10  ../data/artifacts/54/c0a9a2dbba9a42de9f6c771bb...
# 11  ../data/artifacts/54/643dc170ffce40db9d18bf991...
# 12  ../data/artifacts/54/5b66bb947e384682b6c2f6052...
# 13  ../data/artifacts/54/8b7da638541c4e2e8d0b79e4a...
# 14  ../data/artifacts/54/85df0e0eb51342528ef4271cb...
# 15  ../data/artifacts/54/f37b15bf0b0f4b339086c0556...
# 16  ../data/artifacts/54/4e7c93d02f51470fbec737689...
# 17  ../data/artifacts/54/c8472b391916473fb6780ec69...
# 18  ../data/artifacts/54/1f5763a3bd834a6cbd09d718c...
# 19  ../data/artifacts/54/c5224e59cb964154ba9e0148d...
# 20  ../data/artifacts/54/a1186ea7c78943daa5e90f58d...
# 21  ../data/artifacts/54/ed7d6f8984d94418b7fe80857...
# 22  ../data/artifacts/54/2d9ab4360b464f2daa16f2027...
# 23  ../data/artifacts/54/920fde8041f341d2872f481a5...
# 24  ../data/artifacts/54/9ee8e5141711426f88bcb8719...
# 25  ../data/artifacts/54/7df12cb0cbee49f4aa13b934e...
# 26  ../data/artifacts/54/bd073be95b154e698825a9754...
# 31    0.388889          0.388889                   0.444444                2
# 32    0.388889          0.388889                   0.444444                4
# 33    0.133333          0.305556                   0.444444                4
# 34    0.222222          0.361111                   0.555556             None
# 35    0.300000          0.305556                   0.638889             None
# 36    0.300000          0.305556                   0.638889             None
# 37    0.222222          0.361111                   0.555556             None
# 38    0.222222          0.277778                   0.444444                2
# 39    0.222222          0.361111                   0.555556             None
#
#                 params.clf params.ngram_range          params.alpha  \
# 0   RandomForestClassifier                 12                  None
# 1   RandomForestClassifier                 12                  None
# 2            MultinomialNB                 12   0.09920456095726199
# 3   RandomForestClassifier                 12                  None
# 4   RandomForestClassifier                 12                  None
# 5   RandomForestClassifier                 12                  None
# 6   RandomForestClassifier                 12                  None
# 7   RandomForestClassifier                 12                  None
# 8   RandomForestClassifier                 12                  None
# 9   RandomForestClassifier                 12                  None
# 10  RandomForestClassifier                 11                  None
# 11                     SVC                 11                  None
# 12                     SVC                 11                  None
# 13                     SVC                 12                  None
# 14                     SVC                 11                  None
# 15           MultinomialNB                 11   0.02365706569357498
# 16                     SVC                 11                  None
# 17  RandomForestClassifier                 12                  None
# 18  RandomForestClassifier                 12                  None
# 19           MultinomialNB                 11  0.026068140154119183
# 20  RandomForestClassifier                 12                  None
# 21  RandomForestClassifier                 12                  None
# 22  RandomForestClassifier                 12                  None
# 23  RandomForestClassifier                 12                  None
# 24                     SVC                 12                  None
# 25  RandomForestClassifier                 12                  None
# 26  RandomForestClassifier                 12                  None
# 27  RandomForestClassifier                 12                  None
# 28  RandomForestClassifier                 12                  None
# 29  RandomForestClassifier                 12                  None
# 30  RandomForestClassifier                 11                  None
# 31  RandomForestClassifier                 12                  None
# 32  RandomForestClassifier                 12                  None
# 33  RandomForestClassifier                 11                  None
# 34           MultinomialNB                 12   0.02662138406893884
# 35                     SVC                 11                  None
# 36                     SVC                 12                  None
# 37           MultinomialNB                 11  0.015731317462410143
# 38  RandomForestClassifier                 11                  None
# 39           MultinomialNB                 11  0.012753417972236893
#
#                params.C                      tags.mlflow.log-model.history  \
# 0                  None  [{"run_id": "753a0e926ed74dc0810386f554fc10ed"...
# 1                  None  [{"run_id": "fca40f4f11d34b7a97774e648dc9aa28"...
# 2                  None  [{"run_id": "acc5d9d9ac4c4dea89e9d4c1533192c0"...
# 3                  None  [{"run_id": "91bd001e2a2e4a53a76d897b3a26c634"...
# 4                  None  [{"run_id": "c9c286ff1d484e6d9fe0573cf07d318c"...
# 5                  None  [{"run_id": "900681ccdf0b4750bdbbd96d8279d541"...
# 6                  None  [{"run_id": "bc4b00a5e56947728aaa610f30151bee"...
# 7                  None  [{"run_id": "55b0790849b6469ca04a081a068ded81"...
# 8                  None  [{"run_id": "0144359cdcb94b77b6fa8349b425efd2"...
# 9                  None  [{"run_id": "cd5a0960e38d49d6bdd8dca0400b8f60"...
# 10                 None  [{"run_id": "c0a9a2dbba9a42de9f6c771bbf18fe63"...
# 11   0.1743348470586979  [{"run_id": "643dc170ffce40db9d18bf991fb6cfeb"...
# 12   0.1758914497005484  [{"run_id": "5b66bb947e384682b6c2f60520b575b1"...
# 13   0.1433212999490459  [{"run_id": "8b7da638541c4e2e8d0b79e4a899a058"...
# 14  0.15135894230972707  [{"run_id": "85df0e0eb51342528ef4271cb2c9f7dc"...
# 15                 None  [{"run_id": "f37b15bf0b0f4b339086c05565b3a9f7"...
# 16  0.16847788581886447  [{"run_id": "4e7c93d02f51470fbec7376890540380"...
# 17                 None  [{"run_id": "c8472b391916473fb6780ec6953f1657"...
# 18                 None  [{"run_id": "1f5763a3bd834a6cbd09d718cb32f10f"...
# 19                 None  [{"run_id": "c5224e59cb964154ba9e0148dc59ea1a"...
# 20                 None  [{"run_id": "a1186ea7c78943daa5e90f58d03a8093"...
# 21                 None  [{"run_id": "ed7d6f8984d94418b7fe8085740034b3"...
# 22                 None  [{"run_id": "2d9ab4360b464f2daa16f20277f7c1ab"...
# 23                 None  [{"run_id": "920fde8041f341d2872f481a53f8db44"...
# 24  0.18147455288744335  [{"run_id": "9ee8e5141711426f88bcb87192fc45c1"...
# 25                 None  [{"run_id": "7df12cb0cbee49f4aa13b934ed3fce16"...
# 26                 None  [{"run_id": "bd073be95b154e698825a9754c66b851"...
# 27                 None  [{"run_id": "7e25698ff58d48ce89d4378f50364177"...
# 28                 None  [{"run_id": "7be59c30110f4eee8d6fe3173f93d011"...
# 29                 None  [{"run_id": "c904d4dc9fb945ce9081e7870b638039"...
# 30                 None  [{"run_id": "01dceee1951d4203a8038b3b35696cb7"...
# 31                 None  [{"run_id": "4e075d845ae6420384929d630a416a5c"...
# 32                 None  [{"run_id": "4457484e8ee14709acd15586dd1f5686"...
# 33                 None  [{"run_id": "3049264db5aa43519d1289c90d5eda41"...
# 34                 None  [{"run_id": "36fa84abc6b34b878bd16866950be975"...
# 35  0.11972432240201665  [{"run_id": "b3736dd215614ac28925498cffa3d1fa"...
# 36   0.1059217708614404  [{"run_id": "93fb494bbe5e495db87a978e6b89d824"...
# 37                 None  [{"run_id": "c820c40f3e3847aaa7aa6fedb1770786"...
# 38                 None  [{"run_id": "b6360a1cd13f4509ada8d3ca7873a4ad"...
# 39                 None  [{"run_id": "f4a9a0809b1d4f0fb2d76184299b27e9"...
#
#    tags.mlflow.source.type tags.mlflow.user  \
# 0                    LOCAL      apancham002
# 1                    LOCAL      apancham002
# 2                    LOCAL      apancham002
# 3                    LOCAL      apancham002
# 4                    LOCAL      apancham002
# 5                    LOCAL      apancham002
# 6                    LOCAL      apancham002
# 7                    LOCAL      apancham002
# 8                    LOCAL      apancham002
# 9                    LOCAL      apancham002
# 10                   LOCAL      apancham002
# 11                   LOCAL      apancham002
# 12                   LOCAL      apancham002
# 13                   LOCAL      apancham002
# 14                   LOCAL      apancham002
# 15                   LOCAL      apancham002
# 16                   LOCAL      apancham002
# 17                   LOCAL      apancham002
# 18                   LOCAL      apancham002
# 19                   LOCAL      apancham002
# 20                   LOCAL      apancham002
# 21                   LOCAL      apancham002
# 22                   LOCAL      apancham002
# 23                   LOCAL      apancham002
# 24                   LOCAL      apancham002
# 25                   LOCAL      apancham002
# 26                   LOCAL      apancham002
# 27                   LOCAL      apancham002
# 28                   LOCAL      apancham002
# 29                   LOCAL      apancham002
# 30                   LOCAL      apancham002
# 31                   LOCAL      apancham002
# 32                   LOCAL      apancham002
# 33                   LOCAL      apancham002
# 34                   LOCAL      apancham002
# 35                   LOCAL      apancham002
# 36                   LOCAL      apancham002
# 37                   LOCAL      apancham002
# 38                   LOCAL      apancham002
# 39                   LOCAL      apancham002
#
#                               tags.mlflow.source.name
# 0   /Users/apancham002/Applications/anaconda3/envs...
# 1   /Users/apancham002/Applications/anaconda3/envs...
# 2   /Users/apancham002/Applications/anaconda3/envs...
# 3   /Users/apancham002/Applications/anaconda3/envs...
# 4   /Users/apancham002/Applications/anaconda3/envs...
# 5   /Users/apancham002/Applications/anaconda3/envs...
# 6   /Users/apancham002/Applications/anaconda3/envs...
# 7   /Users/apancham002/Applications/anaconda3/envs...
# 8   /Users/apancham002/Applications/anaconda3/envs...
# 9   /Users/apancham002/Applications/anaconda3/envs...
# 10  /Users/apancham002/Applications/anaconda3/envs...
# 11  /Users/apancham002/Applications/anaconda3/envs...
# 12  /Users/apancham002/Applications/anaconda3/envs...
# 13  /Users/apancham002/Applications/anaconda3/envs...
# 14  /Users/apancham002/Applications/anaconda3/envs...
# 15  /Users/apancham002/Applications/anaconda3/envs...
# 16  /Users/apancham002/Applications/anaconda3/envs...
# 17  /Users/apancham002/Applications/anaconda3/envs...
# 18  /Users/apancham002/Applications/anaconda3/envs...
# 19  /Users/apancham002/Applications/anaconda3/envs...
# 20  /Users/apancham002/Applications/anaconda3/envs...
# 21  /Users/apancham002/Applications/anaconda3/envs...
# 22  /Users/apancham002/Applications/anaconda3/envs...
# 23  /Users/apancham002/Applications/anaconda3/envs...
# 24  /Users/apancham002/Applications/anaconda3/envs...
# 25  /Users/apancham002/Applications/anaconda3/envs...
# 26  /Users/apancham002/Applications/anaconda3/envs...
# 27  /Users/apancham002/Applications/anaconda3/envs...
# 28  /Users/apancham002/Applications/anaconda3/envs...
# 29  /Users/apancham002/Applications/anaconda3/envs...
# 30  /Users/apancham002/Applications/anaconda3/envs...
# 31  /Users/apancham002/Applications/anaconda3/envs...
# 32  /Users/apancham002/Applications/anaconda3/envs...
# 33  /Users/apancham002/Applications/anaconda3/envs...
# 34  /Users/apancham002/Applications/anaconda3/envs...
# 35  /Users/apancham002/Applications/anaconda3/envs...
# 36  /Users/apancham002/Applications/anaconda3/envs...
# 37  /Users/apancham002/Applications/anaconda3/envs...
# 38  /Users/apancham002/Applications/anaconda3/envs...
# 39  /Users/apancham002/Applications/anaconda3/envs...
